# %% [markdown]
# ## Linear Regression
#
#
# **Equation of a Line:** $y = mx + b$
#
# **The Goal of Training:** Find the values of $b$ and $m$ that **minimize the MSE**.
#
#
#
# **Slop formula (m) :** (y2 - y1) /(x2 - x1)

# %%
import numpy as np
import matplotlib.pyplot as plt


study_hours = np.random.uniform(2, 10, 50) 
exam_scores = 40 + 6 * study_hours + np.random.normal(0, 5, 50)


plt.figure(figsize=(6, 4))
plt.scatter(study_hours, exam_scores, color='blue', label='Actual Data Points')
plt.xlabel("Study Hours (X)")
plt.ylabel("Exam Score (Y)")
plt.title("Study Hours vs. Exam Score")
plt.grid(True)
plt.legend()
plt.show()

# %%
mean_x = np.mean(study_hours)
mean_y = np.mean(exam_scores)
n = len(study_hours)

print("Mean X:", mean_x)
print("Mean Y:", mean_y)
print("Number of data points:", n)
# Out:
# Mean X: 6.14231172469141
# Mean Y: 76.53446413112042
# Number of data points: 50

# %%
# Calculate numerator for slop(m)
# Σ(xi - x̄)(yi - ȳ)
numerator = np.sum((study_hours - mean_x) * (exam_scores - mean_y))

# Calculate denominator for slop(m)
# Σ(xi - x̄)^2
denominator = np.sum((study_hours - mean_x)**2)


slop_m = numerator / denominator



b = mean_y - slop_m * mean_x

print("slop_m : ",slop_m)
print("b : ",b)
# Out:
# slop_m :  5.8123349617107705
# b :  40.83329094797055

# %%
# prediction
def predict(x_values, b, slop_m):
    return b + slop_m * x_values


y_predicted = predict(study_hours, b, slop_m)
print("y_predicted : ",y_predicted)
# Out:
# y_predicted :  [53.19369775 64.36899353 61.15970459 84.89116781 98.21575953 76.85293732
#  86.29101165 70.58419348 69.25615427 87.93981151 68.48358726 63.33227689
#  94.61055279 81.46153837 95.34246425 78.95548638 89.81076617 87.36188457
#  93.9217836  94.06076347 79.56959297 61.66631623 53.044609   58.43555515
#  76.08776808 91.80114101 97.79877612 92.62428646 83.52486352 81.32558098
#  85.95164855 97.48192851 96.42325403 79.296403   67.89861038 95.66293523
#  86.03141918 54.53927593 54.77000949 67.56325539 94.09594911 71.51551532
#  66.93509958 57.92861594 83.04477053 56.14297227 61.79068094 59.43249735
#  61.13961589 53.10572522]

# %%
print("y_true : ",exam_scores)
# Out:
# y_true :  [60.38666601 66.87096337 58.39715359 84.62707416 95.88548134 80.25001954
#  93.46321156 72.25365013 74.0692115  91.01919338 68.17307338 61.65612714
#  90.27635329 84.2507793  85.10824108 76.59377322 91.80147166 93.47988272
#  96.40130242 95.8467704  82.54604861 62.92064165 59.98647315 53.0230083
#  74.61506125 95.68924776 90.84254209 92.18977756 83.04748716 80.32856417
#  88.45795724 96.20505537 99.20532278 82.69977138 73.26562697 89.40305245
#  84.86372786 44.61556648 52.04353743 61.46366458 91.59223761 70.54296155
#  57.50613242 44.61064554 94.12167284 58.224788   59.20237219 66.52549799
#  58.5136476  57.6607174 ]

# %%
mse = np.mean((exam_scores - y_predicted)**2)
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 24.80

# %%
new_study_hour = 6.5
predicted_score_new = predict(new_study_hour, b, slop_m)
print("predicted_score_new : ",predicted_score_new)
# Out:
# predicted_score_new :  78.61346819909056

# %%
plt.figure(figsize=(8, 6))
plt.scatter(study_hours, exam_scores, color='blue', label='Actual Data Points')
plt.plot(study_hours, y_predicted, color='red', label='Regression Line')
plt.scatter(new_study_hour, predicted_score_new, color='green', marker='X', s=100, label=f'Predicted ({new_study_hour}hrs)')
plt.xlabel("Study Hours (X)")
plt.ylabel("Exam Score (Y)")
plt.title("Simple Linear Regression: Best-Fit Line")
plt.grid(True)
plt.legend()
plt.show()
